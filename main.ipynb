# %%
import torch,torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor

import matplotlib.pyplot as plt

# %%
from torchvision import transforms

transformed_shvn_train = transforms.Compose([

    transforms.RandomRotation(degrees=15),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),

    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),

    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# %%
transformed_shvn_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# %%
transformed_fmnist_train = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomHorizontalFlip(p = 0.5),
    transforms.RandomAffine(degrees = 10, translate=(0.1, 0.1)),

    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])

])

transformed_fmnist_test = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# %%
transformed_cifar_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(p = 0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

transformed_cifar_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# %%
cifar_data_train = datasets.CIFAR10(
    root='data/CIFAR10', 
    train=True, 
    download=True,
    transform=transformed_cifar_train
)

cifar_data_test = datasets.CIFAR10(
    root='data/CIFAR10',
    train=False,
    download=True,
    transform=transformed_cifar_test
)
# Out:
# Downloading https://cave.cs.toronto.edu/kriz/cifar-10-python.tar.gz to data/CIFAR10\cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [25:37<00:00, 111kB/s]
# Extracting data/CIFAR10\cifar-10-python.tar.gz to data/CIFAR10
# c:\Users\JAY\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Files already downloaded and verified

# %%
train_data_FMNIST = datasets.FashionMNIST(
    root="data",
    train = True,
    download = True,
    transform= ToTensor(),
    target_transform= None
)

test_data_FMNIST = datasets.FashionMNIST(
    root= "data",
    train = False,
    download=True,
    transform=ToTensor()

)

# %%
svhn_data_train = datasets.SVHN(
    root='./data/SVHN/train', 
    split='train', 
    download=True,
    transform=transformed_shvn_train
)

svhn_data_test = datasets.SVHN(
    root='./data/SVHN/test',
    split='test',
    download=True,
    transform=transformed_shvn_test
)
# Out:
# Using downloaded and verified file: ./data/SVHN/train\train_32x32.mat
# Using downloaded and verified file: ./data/SVHN/test\test_32x32.mat

# %%
img,label = svhn_data_train[0]

# %%
print(img)
print(label)
# Out:
# tensor([[[-0.9843, -0.9843, -0.9843,  ..., -0.2314, -0.2471, -0.3098],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.2863, -0.3569, -0.6078],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.7098, -0.7490, -0.7490],
#          ...,
#          [-0.9843, -0.9843, -0.9843,  ..., -0.0510, -0.0431, -0.9843],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.9843, -0.9843, -0.9843],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.9843, -0.9843, -0.9843]],
#
#         [[-0.9843, -0.9843, -0.9843,  ..., -0.3020, -0.3176, -0.3647],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.3333, -0.4431, -0.6784],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.7098, -0.7725, -0.7725],
#          ...,
#          [-0.9843, -0.9843, -0.9843,  ..., -0.0980, -0.0980, -0.9843],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.9843, -0.9843, -0.9843],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.9843, -0.9843, -0.9843]],
#
#         [[-0.9843, -0.9843, -0.9843,  ..., -0.5137, -0.4431, -0.4902],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.4196, -0.4745, -0.5686],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.6078, -0.6235, -0.6235],
#          ...,
#          [-0.9843, -0.9843, -0.9843,  ..., -0.2627, -0.2784, -0.9843],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.9843, -0.9843, -0.9843],
#          [-0.9843, -0.9843, -0.9843,  ..., -0.9843, -0.9843, -0.9843]]])
# 1

# %%
class_names = train_data_FMNIST.classes
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
train_data = datasets.MNIST(
    root="data",
    train = True,
    download = True,
    transform= ToTensor(),
    target_transform= None
)

test_data = datasets.MNIST(
    root= "data",
    train = False,
    download=True,
    transform=ToTensor()

)
